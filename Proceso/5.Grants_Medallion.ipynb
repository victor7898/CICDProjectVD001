# %% [markdown]
# ##Grants

# %%
# %sql
GRANT SELECT ON SCHEMA catalog_au.golden TO `Analytics`;

# %%
# %sql
GRANT SELECT ON SCHEMA catalog_au.golden TO `DataScientist`;
GRANT SELECT ON SCHEMA catalog_au.silver TO `DataScientist`;

# %%
# %sql
GRANT SELECT, MODIFY ON CATALOG catalog_au TO `Engineer`;

# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG catalog_au TO `DBA`;
