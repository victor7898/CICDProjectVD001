# %%
# %sql
DROP SHARE IF EXISTS Golden_Tables;

# %%
# %sql
CREATE SHARE Golden_Tables

# %%
# %sql
ALTER SHARE Golden_Tables
ADD TABLE catalog_au.golden.gold_purchase_patterns;
WITH HISTORY

# %%
# %sql
ALTER SHARE Golden_Tables
ADD TABLE catalog_au.golden.gold_reorder_rate_department;
WITH HISTORY

# %%
# %sql
ALTER SHARE Golden_Tables
ADD TABLE catalog_au.golden.gold_top_products;
WITH HISTORY

# %%
# %sql
ALTER SHARE Golden_Tables
ADD TABLE catalog_au.golden.gold_user_segments;
WITH HISTORY

# %%
# %sql
ALTER SHARE Golden_Tables
ADD TABLE catalog_au.golden.golden_top_productscatalog_au.bronze.bronze_aisle
WITH HISTORY

# %%
# %sql
CREATE RECIPIENT ExternalCompany
