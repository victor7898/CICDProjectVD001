-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
dbutils.widgets.text("nameContainer","metastore")
dbutils.widgets.text("nameStorage","adbstoragevd001")
dbutils.widgets.text("catalogo","catalog_au")

-- %%
%python

nameContainer = dbutils.widgets.get("nameContainer")
nameStorage = dbutils.widgets.get("nameStorage")
catalogo = dbutils.widgets.get("catalogo")
ruta = f"abfss://{nameContainer}@{nameStorage}.dfs.core.windows.net"

-- %% [markdown]
-- ### Eliminacion tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_aisle;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_department;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_order_products__prior;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_order_products__train;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_orders;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_products;
DROP TABLE IF EXISTS ${catalogo}.bronze.bronze_sample_submission;

-- %%
%python
## REMOVE DATA (Bronze)
dbutils.fs.rm(f"{ruta}/aisle", True)
dbutils.fs.rm(f"{ruta}/department", True)
dbutils.fs.rm(f"{ruta}/order_products__prior", True)
dbutils.fs.rm(f"{ruta}/order_products__train", True)
dbutils.fs.rm(f"{ruta}/orders", True)
dbutils.fs.rm(f"{ruta}/products", True)
dbutils.fs.rm(f"{ruta}/sample_submission", True)

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.silver.silver_orders;
DROP TABLE IF EXISTS ${catalogo}.silver.silver_order_products;
DROP TABLE IF EXISTS ${catalogo}.silver.silver_Products;
DROP TABLE IF EXISTS ${catalogo}.silver.silver_orders_products_detail;

-- %%
%python
# REMOVE DATA (Silver)
# dbutils.fs.rm(f"{ruta}/tablas/VENTAS_LIMPIAS", True)
# dbutils.fs.rm(f"{ruta}/tablas/CLIENTES_VALIDOS", True)
# dbutils.fs.rm(f"{ruta}/tablas/DETALLE_PRODUCTOS", True)

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.golden.golden_top_products;
DROP TABLE IF EXISTS ${catalogo}.golden.gold_reorder_rate_department;
DROP TABLE IF EXISTS ${catalogo}.golden.gold_purchase_patterns;
DROP TABLE IF EXISTS ${catalogo}.golden.gold_user_segments;

-- %%
%python
# REMOVE DATA (Golden)
# dbutils.fs.rm(f"{ruta}/tablas/KPIS_VENTAS", True)
# dbutils.fs.rm(f"{ruta}/tablas/SEGMENTOS_CLIENTES", True)
